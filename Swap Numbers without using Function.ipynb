# %% [markdown]
# # Swap Numbers Without using Function

# %%
a=int(input("Enter first Number:"))
b=int(input("Enter second Number:"))
a=a+b
b=a-b
a=a-b
print(a,b)
# Out:
# Enter first Number: 10
# Enter second Number: 7
# 7 10
